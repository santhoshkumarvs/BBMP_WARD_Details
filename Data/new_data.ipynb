# %%
import pandas as pd

# %%
import numpy as np

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import mean_squared_error

# %%
from sklearn.metrics import mean_absolute_error

# %%
In [2]: data = pd.read_csv("eco.csv")

# %%
data
# Out:
#                     ward_Name  distance  Total_population  male_population  \
# 0             Kempegowda Ward   14.5092             42913            22239
# 1            Chowdeswari Ward    3.3692             42775            22369
# 2                      Atturu    8.2692             42569            22772
# 3    Yelahanka Satellite Town    4.6869             43243            22475
# 4                      Kogilu   17.1989             40396            21229
# ..                        ...       ...               ...              ...
# 220                Hsr Layout    4.2210             38763            20138
# 221                    Ibluru    3.7151             33851            17764
# 222           Mangammanapalya    1.6594             40149            21038
# 223                 Hosa Road    3.2714             33979            18432
# 224                     Kudlu    3.3325             16757             9054
#
#      female_population
# 0                20674
# ...

# %%
features = ['Total_population', 'male_population', 'female_population', 'ward_Name', 'distance']

# %%
features
# Out:
# ['Total_population',
#  'male_population',
#  'female_population',
#  'ward_Name',
#  'distance']

# %%
df = data[features]

# %%
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df[['male_population', 'female_population', 'ward_Name', 'distance']], df['Total_population'], test_size=0.2, random_state=42)

# %%
# Train Linear Regression model
model = LinearRegression()
model.fit(X_train, y_train)
print(X_train.shape)
print(y_train.shape)
print(X_train.dtypes)
print(y_train.dtype)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11768\1106452106.py in ?()
#       1 # Train Linear Regression model
#       2 model = LinearRegression()
# ----> 3 model.fit(X_train, y_train)
#       4 print(X_train.shape)
#       5 print(y_train.shape)
#       6 print(X_train.dtypes)
#
# ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1469                 skip_parameter_validation=(
#    1470                     prefer_skip_nested_validation or global_skip_validation
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#
# ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_base.py in ?(self, X, y, sample_weight)
#     605         n_jobs_ = self.n_jobs
#     606
# ...
