# %%
 import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge, Lasso
from sklearn.metrics import mean_squared_error

# %%
data = pd.read_csv('eco.csv')

# %%
X_train, X_test, y_train, y_test = train_test_split(data.drop('target', axis=1), data['target'], test_size=0.2, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(data.drop('target', axis=1), data['target'], test_size=0.2, random_state=42)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
# ...

# %%
print(data.columns)
# Out:
# Index(['ward_Name', 'distance', 'Total_population', 'male_population',
#        'female_population'],
#       dtype='object')

# %%
X_train, X_test, y_train, y_test = train_test_split(data.drop(['ward_Name', 'Total_population'], axis=1), data['Total_population'], test_size=0.2, random_state=42)

# %%
ridge_model = Ridge(alpha=1.0)
ridge_model.fit(X_train, y_train)
# Out:
# Ridge()

# %%
#Train a Lasso Regression model:

lasso_model = Lasso(alpha=0.1)
lasso_model.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.1)

# %%
ridge_mse = mean_squared_error(y_test, ridge_model.predict(X_test))
lasso_mse = mean_squared_error(y_test, lasso_model.predict(X_test))

# %%
print(f'Ridge MSE: {ridge_mse:.2f}')
print(f'Lasso MSE: {lasso_mse:.2f}')
# Out:
# Ridge MSE: 0.00
# Lasso MSE: 0.05

# %%
The results show that:

- Ridge Regression has a Mean Squared Error (MSE) of 0.00, which indicates a perfect fit (or overfitting).
- Lasso Regression has an MSE of 0.05, which suggests a relatively good fit, but not as perfect as Ridge.
